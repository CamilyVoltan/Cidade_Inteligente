# %% [markdown]
# <a href="https://colab.research.google.com/github/CamilyVoltan/smart-city/blob/main/smart-city.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***CIDADE INTELIGENTE***

# %%
#BIBLIOTECAS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd_int = pd.read_excel("CIDADE_INT - FILTRADA.xlsx")
cd_int
# Out:
#                         Cidade Estado  População total estimada do município  \
# 0                     Paulínia     SP                                 109424
# 1                      Triunfo     RS                                  29538
# 2                     Louveira     SP                                  48885
# 3           Presidente Kennedy     ES                                  11574
# 4    São Gonçalo do Rio Abaixo     MG                                  10920
# ..                         ...    ...                                    ...
# 126                    Urucará     AM                                  16256
# 127           Senador Guiomard     AC                                  23024
# 128                    Codajás     AM                                  28637
# 129                     Bujari     AC                                  10266
# 130                 Acrelândia     AC                                  15256
#
# ...

# %% [markdown]
# **GRÁFICOS RELATIVOS**

# %%
plt.bar(cd_int["Estado"], cd_int["PIB per capita do município"], color="b")
plt.title("PIB por Estado no Brasil")
plt.xlabel("Estado")
plt.ylabel("PIB")
plt.show()

# %%
sns.barplot(data=cd_int, y ='Taxa de analfabetismo',x = 'Estado', hue='Estado')

plt.title('Taxa de analfabetismo no Brasil')
plt.ylabel('Taxa de analfabetismo')
# Out:
# Text(0, 0.5, 'Taxa de analfabetismo')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ***REGIÕES DO BRASIL***

# %% [markdown]
# **REGIÃO NORTE**

# %%
norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
norte = cd_int[cd_int['Estado'].isin(norte)]

plt.bar(norte['Cidade'], norte['PIB per capita do município'], color='skyblue')
plt.title('PIB per Capita das Cidades do Norte')
plt.xlabel('Cidade')
plt.ylabel('PIB per Capita')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
norte = cd_int[cd_int['Estado'].isin(norte)]

plt.bar(norte['Estado'], norte['População ocupada com vínculo formal'], color='skyblue')
plt.title('População ocupada com vínculo formal')
plt.xlabel('Estado')
plt.ylabel('População estimada')
# Out:
# Text(0, 0.5, 'População estimada')

# %%
norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
norte = cd_int[cd_int['Estado'].isin(norte)]

plt.bar(norte['Estado'], norte['Índice de desenvolvimento da educação básica (IDEB) - anos finais'], color='skyblue')
plt.title('IDEB')
plt.xlabel('Estado')
plt.ylabel('IDEB')
plt.show()

# %%
norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
norte = cd_int[cd_int['Estado'].isin(norte)]

plt.bar(norte['Estado'], norte['Leitos hospitalares na rede pública municipal'], color='skyblue')
plt.title('Leitos em Hospitais')
plt.xlabel('Estado')
plt.ylabel('Leitos hospitalares na rede pública municipal')
plt.show()

# %%
norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
norte = cd_int[cd_int['Estado'].isin(norte)]

plt.bar(norte['Estado'], norte['Taxa de homicídios'], color='skyblue')
plt.title('Taxa de homicídios')
plt.xlabel('Estado')
plt.ylabel('Taxa de homicídios')
plt.show()

# %%
norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
norte = cd_int[cd_int['Estado'].isin(norte)]

plt.bar(norte['Estado'], norte['Políticas públicas e ações para segurança pública'], color='skyblue')
plt.title('Políticas públicas e ações para segurança pública')
plt.xlabel('Estado')
plt.ylabel('Políticas públicas e ações para segurança pública')
plt.show()

# %%
norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
norte = cd_int[cd_int['Estado'].isin(norte)]

plt.bar(norte['Estado'], norte['Proteção e gestão do meio ambiente e áreas verdes do município'], color='skyblue')
plt.title('Proteção e gestão do meio ambiente e áreas verdes do município')
plt.xlabel('Estado')
plt.ylabel('Proteção e gestão do meio ambiente e áreas verdes do município')
plt.show()

# %%
norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
norte = cd_int[cd_int['Estado'].isin(norte)]

plt.bar(norte['Estado'], norte['Vulnerabilidade a riscos e desastres naturais'], color='skyblue')
plt.title('Vulnerabilidade a riscos e desastres naturais')
plt.xlabel('Estado')
plt.ylabel('Vulnerabilidade a riscos e desastres naturais')
plt.show()

# %%
norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
norte = cd_int[cd_int['Estado'].isin(norte)]

plt.bar(norte['Estado'], norte['Taxa de analfabetismo'], color='skyblue')
plt.title('Taxa de analfabetismo')
plt.xlabel('Estado')
plt.ylabel('Taxa de analfabetismo')
plt.show()

# %%
norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
norte = cd_int[cd_int['Estado'].isin(norte)]

plt.bar(norte['Estado'], norte['Computadores para uso dos alunos'], color='skyblue')
plt.title('Computadores para uso dos alunos')
plt.xlabel('Estado')
plt.ylabel('Computadores para uso dos alunos')
plt.show()

# %%
norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
norte = cd_int[cd_int['Estado'].isin(norte)]

plt.bar(norte['Estado'], norte['Estrutura de equipamentos culturais e esportivos'], color='skyblue')
plt.title('Estrutura de equipamentos culturais e esportivos')
plt.xlabel('Estado')
plt.ylabel('Estrutura de equipamentos culturais e esportivos')
plt.show()

# %% [markdown]
# REGIÃO NORDESTE

# %%
nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
nordeste = cd_int[cd_int['Estado'].isin(nordeste)]

plt.bar(nordeste['Cidade'], nordeste['PIB per capita do município'], color='skyblue')
plt.title('PIB per Capita das Cidades do Nordeste')
plt.xlabel('Cidade')
plt.ylabel('PIB per Capita')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
nordeste = cd_int[cd_int['Estado'].isin(nordeste)]

plt.bar(nordeste['Estado'], nordeste['População ocupada com vínculo formal'], color='skyblue')
plt.title('População ocupada com vínculo formal')
plt.xlabel('Estado')
plt.ylabel('População estimada')
plt.show()

# %%
nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
nordeste = cd_int[cd_int['Estado'].isin(nordeste)]

plt.bar(nordeste['Estado'], nordeste['Índice de desenvolvimento da educação básica (IDEB) - anos finais'], color='skyblue')
plt.title('IDEB')
plt.xlabel('Estado')
plt.ylabel('IDEB')
plt.show()

# %%
nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
nordeste = cd_int[cd_int['Estado'].isin(nordeste)]

plt.bar(nordeste['Estado'], nordeste['Leitos hospitalares na rede pública municipal'], color='skyblue')
plt.title('Leitos em Hospitais')
plt.xlabel('Estado')
plt.ylabel('Leitos hospitalares na rede pública municipal')
plt.show()

# %%
nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
nordeste = cd_int[cd_int['Estado'].isin(nordeste)]

plt.bar(nordeste['Estado'], nordeste['Taxa de homicídios'], color='skyblue')
plt.title('Taxa de homicídios')
plt.xlabel('Estado')
plt.ylabel('Taxa de homicídios')
plt.show()

# %%
nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
nordeste = cd_int[cd_int['Estado'].isin(nordeste)]

plt.bar(nordeste['Estado'], nordeste['Políticas públicas e ações para segurança pública'], color='skyblue')
plt.title('Políticas públicas e ações para segurança pública')
plt.xlabel('Estado')
plt.ylabel('Políticas públicas e ações para segurança pública')
plt.show()

# %%
nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
nordeste = cd_int[cd_int['Estado'].isin(nordeste)]

plt.bar(nordeste['Estado'], nordeste['Proteção e gestão do meio ambiente e áreas verdes do município'], color='skyblue')
plt.title('Proteção e gestão do meio ambiente e áreas verdes do município')
plt.xlabel('Estado')
plt.ylabel('Proteção e gestão do meio ambiente e áreas verdes do município')
plt.show()

# %%
nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
nordeste = cd_int[cd_int['Estado'].isin(nordeste)]

plt.bar(nordeste['Estado'], nordeste['Vulnerabilidade a riscos e desastres naturais'], color='skyblue')
plt.title('Vulnerabilidade a riscos e desastres naturais')
plt.xlabel('Estado')
plt.ylabel('Vulnerabilidade a riscos e desastres naturais')
plt.show()

# %%
nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
nordeste = cd_int[cd_int['Estado'].isin(nordeste)]

plt.bar(nordeste['Estado'], nordeste['Taxa de analfabetismo'], color='skyblue')
plt.title('Taxa de analfabetismo')
plt.xlabel('Estado')
plt.ylabel('Taxa de analfabetismo')
plt.show()

# %%
nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
nordeste = cd_int[cd_int['Estado'].isin(nordeste)]

plt.bar(nordeste['Estado'], nordeste['Computadores para uso dos alunos'], color='skyblue')
plt.title('Computadores para uso dos alunos')
plt.xlabel('Estado')
plt.ylabel('Computadores para uso dos alunos')
plt.show()

# %%
nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
nordeste = cd_int[cd_int['Estado'].isin(nordeste)]

plt.bar(nordeste['Estado'], nordeste['Estrutura de equipamentos culturais e esportivos'], color='skyblue')
plt.title('Estrutura de equipamentos culturais e esportivos')
plt.xlabel('Estado')
plt.ylabel('Estrutura de equipamentos culturais e esportivos')
plt.show()

# %% [markdown]
# REGIÃO CENTRO-OESTE

# %%
centro_oeste = ['GO', 'MT', 'MS']
centro_oeste = cd_int[cd_int['Estado'].isin(centro_oeste)]

plt.bar(centro_oeste['Cidade'], centro_oeste['PIB per capita do município'], color='skyblue')
plt.title('PIB per Capita das Cidades do Centro-Oeste')
plt.xlabel('Cidade')
plt.ylabel('PIB per Capita')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
centro_oeste = ['GO', 'MT', 'MS']
centro_oeste = cd_int[cd_int['Estado'].isin(centro_oeste)]

plt.bar(centro_oeste['Estado'], centro_oeste['População ocupada com vínculo formal'], color='skyblue')
plt.title('População ocupada com vínculo formal')
plt.xlabel('Estado')
plt.ylabel('População estimada')
plt.show()

# %%
centro_oeste = ['GO', 'MT', 'MS']
centro_oeste = cd_int[cd_int['Estado'].isin(centro_oeste)]

plt.bar(centro_oeste['Estado'], centro_oeste['Índice de desenvolvimento da educação básica (IDEB) - anos finais'], color='skyblue')
plt.title('IDEB')
plt.xlabel('Estado')
plt.ylabel('IDEB')
plt.show()

# %%
centro_oeste = ['GO', 'MT', 'MS']
centro_oeste = cd_int[cd_int['Estado'].isin(centro_oeste)]

plt.bar(centro_oeste['Estado'], centro_oeste['Leitos hospitalares na rede pública municipal'], color='skyblue')
plt.title('Leitos em Hospitais')
plt.xlabel('Estado')
plt.ylabel('Leitos hospitalares na rede pública municipal')
plt.show()

# %%
centro_oeste = ['GO', 'MT', 'MS']
centro_oeste = cd_int[cd_int['Estado'].isin(centro_oeste)]

plt.bar(centro_oeste['Estado'], centro_oeste['Taxa de homicídios'], color='skyblue')
plt.title('Taxa de homicídios')
plt.xlabel('Estado')
plt.ylabel('Taxa de homicídios')
plt.show()

# %%
centro_oeste = ['GO', 'MT', 'MS']
centro_oeste = cd_int[cd_int['Estado'].isin(centro_oeste)]

plt.bar(centro_oeste['Estado'], centro_oeste['Políticas públicas e ações para segurança pública'], color='skyblue')
plt.title('Políticas públicas e ações para segurança pública')
plt.xlabel('Estado')
plt.show()

# %%
centro_oeste = ['GO', 'MT', 'MS']
centro_oeste = cd_int[cd_int['Estado'].isin(centro_oeste)]

plt.bar(centro_oeste['Estado'], centro_oeste['Proteção e gestão do meio ambiente e áreas verdes do município'], color='skyblue')
plt.title('Proteção e gestão do meio ambiente e áreas verdes do município')
plt.xlabel('Estado')
plt.ylabel('Proteção e gestão do meio ambiente e áreas verdes do município')
plt.show()

# %%
centro_oeste = ['GO', 'MT', 'MS']
centro_oeste = cd_int[cd_int['Estado'].isin(centro_oeste)]

plt.bar(centro_oeste['Estado'], centro_oeste['Vulnerabilidade a riscos e desastres naturais'], color='skyblue')
plt.title('Vulnerabilidade a riscos e desastres naturais')
plt.xlabel('Estado')
plt.ylabel('')
plt.show()

# %%
centro_oeste = ['GO', 'MT', 'MS']
centro_oeste = cd_int[cd_int['Estado'].isin(centro_oeste)]

plt.bar(centro_oeste['Estado'], centro_oeste['Taxa de analfabetismo'], color='skyblue')
plt.title('Taxa de analfabetismo')
plt.xlabel('Estado')
plt.ylabel('Taxa de analfabetismo')
plt.show()

# %%
centro_oeste = ['GO', 'MT', 'MS']
centro_oeste = cd_int[cd_int['Estado'].isin(centro_oeste)]

plt.bar(centro_oeste['Estado'], centro_oeste['Computadores para uso dos alunos'], color='skyblue')
plt.title('Computadores para uso dos alunos')
plt.xlabel('Estado')
plt.ylabel('Computadores para uso dos alunos')
plt.show()

# %%
centro_oeste = ['GO', 'MT', 'MS']
centro_oeste = cd_int[cd_int['Estado'].isin(centro_oeste)]

plt.bar(centro_oeste['Estado'], centro_oeste['Estrutura de equipamentos culturais e esportivos'], color='skyblue')
plt.title('Estrutura de equipamentos culturais e esportivos')
plt.xlabel('Estado')
plt.ylabel('')
plt.show()

# %% [markdown]
# REGIÃO SUDESTE

# %%
sudeste = ['ES', 'MG', 'RJ', 'SP']
sudeste = cd_int[cd_int['Estado'].isin(sudeste)]

plt.bar(sudeste['Cidade'], sudeste['PIB per capita do município'], color='skyblue')
plt.title('PIB per Capita das Cidades do Sudeste')
plt.xlabel('Cidade')
plt.ylabel('PIB per Capita')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
sudeste = ['ES', 'MG', 'RJ', 'SP']
sudeste = cd_int[cd_int['Estado'].isin(sudeste)]

plt.bar(sudeste['Estado'], sudeste['População ocupada com vínculo formal'], color='skyblue')
plt.title('População ocupada com vínculo formal')
plt.xlabel('Estado')
plt.ylabel('População estimada')
# Out:
# Text(0, 0.5, 'População estimada')

# %%
sudeste = ['ES', 'MG', 'RJ', 'SP']
sudeste = cd_int[cd_int['Estado'].isin(sudeste)]

plt.bar(sudeste['Estado'], sudeste['Índice de desenvolvimento da educação básica (IDEB) - anos finais'], color='skyblue')
plt.title('IDEB')
plt.xlabel('Estado')
plt.ylabel('IDEB')
plt.show()

# %%
sudeste = ['ES', 'MG', 'RJ', 'SP']
sudeste = cd_int[cd_int['Estado'].isin(sudeste)]

plt.bar(sudeste['Estado'], sudeste['Leitos hospitalares na rede pública municipal'], color='skyblue')
plt.title('Leitos em Hospitais')
plt.xlabel('Estado')
plt.ylabel('Leitos hospitalares na rede pública municipal')
plt.show()

# %%
sudeste = ['ES', 'MG', 'RJ', 'SP']
sudeste = cd_int[cd_int['Estado'].isin(sudeste)]

plt.bar(sudeste['Estado'], sudeste['Taxa de homicídios'], color='skyblue')
plt.title('Taxa de homicídios')
plt.xlabel('Estado')
plt.ylabel('Taxa de homicídios')
plt.show()

# %%
sudeste = ['ES', 'MG', 'RJ', 'SP']
sudeste = cd_int[cd_int['Estado'].isin(sudeste)]

plt.bar(sudeste['Estado'], sudeste['Políticas públicas e ações para segurança pública'], color='skyblue')
plt.title('Políticas públicas e ações para segurança pública')
plt.xlabel('Estado')
plt.ylabel('Políticas públicas e ações para segurança pública')
plt.show()

# %%
sudeste = ['ES', 'MG', 'RJ', 'SP']
sudeste = cd_int[cd_int['Estado'].isin(sudeste)]

plt.bar(sudeste['Estado'], sudeste['Proteção e gestão do meio ambiente e áreas verdes do município'], color='skyblue')
plt.title('Proteção e gestão do meio ambiente e áreas verdes do município')
plt.xlabel('Estado')
plt.ylabel('Proteção e gestão do meio ambiente e áreas verdes do município')
plt.show()

# %%
sudeste = ['ES', 'MG', 'RJ', 'SP']
sudeste = cd_int[cd_int['Estado'].isin(sudeste)]

plt.bar(sudeste['Estado'], sudeste['Vulnerabilidade a riscos e desastres naturais'], color='skyblue')
plt.title('Vulnerabilidade a riscos e desastres naturais')
plt.xlabel('Estado')
plt.ylabel('Vulnerabilidade a riscos e desastres naturais')
plt.show()

# %%
sudeste = ['ES', 'MG', 'RJ', 'SP']
sudeste = cd_int[cd_int['Estado'].isin(sudeste)]

plt.bar(sudeste['Estado'], sudeste['Taxa de analfabetismo'], color='skyblue')
plt.title('Taxa de analfabetismo')
plt.xlabel('Estado')
plt.ylabel('Taxa de analfabetismo')
plt.show()

# %%
sudeste = ['ES', 'MG', 'RJ', 'SP']
sudeste = cd_int[cd_int['Estado'].isin(sudeste)]

plt.bar(sudeste['Estado'], sudeste['Computadores para uso dos alunos'], color='skyblue')
plt.title('Computadores para uso dos alunos')
plt.xlabel('Estado')
plt.ylabel('Computadores para uso dos alunos')
plt.show()

# %%
sudeste = ['ES', 'MG', 'RJ', 'SP']
sudeste = cd_int[cd_int['Estado'].isin(sudeste)]

plt.bar(sudeste['Estado'], sudeste['Estrutura de equipamentos culturais e esportivos'], color='skyblue')
plt.title('Estrutura de equipamentos culturais e esportivos')
plt.xlabel('Estado')
plt.ylabel('Esquipamentos culturais e esportivos')
plt.show()

# %% [markdown]
# REGIÃO SUL

# %%
sul = ['SC', 'RS', 'PR']
sul = cd_int[cd_int['Estado'].isin(sul)]

plt.bar(sul['Cidade'], sul['PIB per capita do município'], color='skyblue')
plt.title('PIB per Capita das Cidades do Sul')
plt.xlabel('Cidade')
plt.ylabel('PIB per Capita')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
sul = ['SC', 'RS', 'PR']
sul = cd_int[cd_int['Estado'].isin(sul)]

plt.bar(sul['Estado'], sul['População ocupada com vínculo formal'], color='skyblue')
plt.title('População ocupada com vínculo formal')
plt.xlabel('Estado')
plt.ylabel('População estimada')
plt.show()

# %%
sul = ['SC', 'RS', 'PR']
sul = cd_int[cd_int['Estado'].isin(sul)]

plt.bar(sul['Estado'], sul['Índice de desenvolvimento da educação básica (IDEB) - anos finais'], color='skyblue')
plt.title('IDEB')
plt.xlabel('Estado')
plt.ylabel('IDEB')
plt.show()

# %%
sul = ['SC', 'RS', 'PR']
sul = cd_int[cd_int['Estado'].isin(sul)]

plt.bar(sul['Estado'], sul['Leitos hospitalares na rede pública municipal'], color='skyblue')
plt.title('Leitos em Hospitais')
plt.xlabel('Estado')
plt.ylabel('Leitos hospitalares na rede pública municipal')
plt.show()

# %%
sul = ['SC', 'RS', 'PR']
sul = cd_int[cd_int['Estado'].isin(sul)]

plt.bar(sul['Estado'], sul['Taxa de homicídios'], color='skyblue')
plt.title('Taxa de homicídios')
plt.xlabel('Estado')
plt.ylabel('Taxa de homicídios')
plt.show()

# %%
sul = ['SC', 'RS', 'PR']
sul = cd_int[cd_int['Estado'].isin(sul)]

plt.bar(sul['Estado'], sul['Políticas públicas e ações para segurança pública'], color='skyblue')
plt.title('Políticas públicas e ações para segurança pública')
plt.xlabel('Estado')
plt.ylabel('Políticas públicas e ações para segurança pública')
# Out:
# Text(0, 0.5, 'Políticas públicas e ações para segurança pública')

# %%
sul = ['SC', 'RS', 'PR']
sul = cd_int[cd_int['Estado'].isin(sul)]

plt.bar(sul['Estado'], sul['Proteção e gestão do meio ambiente e áreas verdes do município'], color='skyblue')
plt.title('Proteção e gestão do meio ambiente e áreas verdes do município')
plt.xlabel('Estado')
plt.ylabel('Proteção e gestão do meio ambiente e áreas verdes do município')
plt.show()

# %%
sul = ['SC', 'RS', 'PR']
sul = cd_int[cd_int['Estado'].isin(sul)]

plt.bar(sul['Estado'], sul['Vulnerabilidade a riscos e desastres naturais'], color='skyblue')
plt.title('Vulnerabilidade a riscos e desastres naturais')
plt.xlabel('Estado')
plt.ylabel('Vulnerabilidade a riscos e desastres naturais')
plt.show()

# %%
sul = ['SC', 'RS', 'PR']
sul = cd_int[cd_int['Estado'].isin(sul)]

plt.bar(sul['Estado'], sul['Taxa de analfabetismo'], color='skyblue')
plt.title('Taxa de analfabetismo')
plt.xlabel('Estado')
plt.ylabel('Taxa de analfabetismo')
plt.show()

# %%
sul = ['SC', 'RS', 'PR']
sul = cd_int[cd_int['Estado'].isin(sul)]

plt.bar(sul['Estado'], sul['Computadores para uso dos alunos'], color='skyblue')
plt.title('Computadores para uso dos alunos')
plt.xlabel('Estado')
plt.ylabel('Computadores para uso dos alunos')
plt.show()

# %%
sul = ['SC', 'RS', 'PR']
sul = cd_int[cd_int['Estado'].isin(sul)]

plt.bar(sul['Estado'], sul['Estrutura de equipamentos culturais e esportivos'], color='skyblue')
plt.title('Estrutura de equipamentos culturais e esportivos')
plt.xlabel('Estado')
plt.ylabel('Estrutura de equipamentos culturais e esportivos')
plt.show()
